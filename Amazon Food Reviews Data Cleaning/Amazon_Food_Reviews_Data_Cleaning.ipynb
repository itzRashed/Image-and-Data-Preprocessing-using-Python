# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sms
df = pd.read_csv("/content/drive/MyDrive/Datasets/Reviews.csv")
small_data = df.sample(frac=0.1, random_state=42)
df.shape
df.head(10)
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# 5   6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
# 6   7  B006K2ZZ7K  A1SP2KVKFXXRU1                David C. Sullivan
# 7   8  B006K2ZZ7K  A3JRGQVEQN31IQ               Pamela G. Williams
# 8   9  B000E7L2R4  A1MZYO9TZK0BBI                         R. James
# 9  10  B00171APVA  A21BT40VZCCYT4                    Carol A. Reed
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %%
#Example of dropping column
df.drop(['ProductId','Score'],axis =1)
# Out:
#             Id          UserId                      ProfileName  \
# 0            1  A3SGXH7AUHU8GW                       delmartian
# 1            2  A1D87F6ZCVE5NK                           dll pa
# 2            3   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  A395BORC6FGVXV                             Karl
# 4            5  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...             ...                              ...
# 568449  568450  A28KG5XORO54AY                 Lettie D. Carter
# 568450  568451  A3I8AFVPEE8KI5                        R. Sawyer
# 568451  568452  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568453  568454  A3LGQPJCZVL9UC                         srfell17
#
#         HelpfulnessNumerator  HelpfulnessDenominator        Time  \
# 0                          1                       1  1303862400
# ...

# %%
#Rename our column
df = df.rename(columns={'UserId': 'User_Id'})

# %%
df.head(10)
# Out:
#    Id   ProductId         User_Id                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# 5   6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
# 6   7  B006K2ZZ7K  A1SP2KVKFXXRU1                David C. Sullivan
# 7   8  B006K2ZZ7K  A3JRGQVEQN31IQ               Pamela G. Williams
# 8   9  B000E7L2R4  A1MZYO9TZK0BBI                         R. James
# 9  10  B00171APVA  A21BT40VZCCYT4                    Carol A. Reed
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# ...

# %%
#Shows null values
df.isna().sum()
# Out:
# Id                         0
# ProductId                  0
# User_Id                    0
# ProfileName               16
# HelpfulnessNumerator       0
# HelpfulnessDenominator     0
# Score                      0
# Time                       0
# Summary                   27
# Text                       0
# dtype: int64

# %%
#Checks duplicate values over the whole dataset
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Id, ProductId, User_Id, ProfileName, HelpfulnessNumerator, HelpfulnessDenominator, Score, Time, Summary, Text]
# Index: []

# %%
#Checks duplicate values over a specific column
df.loc[df.duplicated(subset = ['ProductId'])].head(10)
# Out:
#     Id   ProductId         User_Id          ProfileName  HelpfulnessNumerator  \
# 5    6  B006K2ZZ7K   ADT0SRK1MGOEU       Twoapennything                     0
# 6    7  B006K2ZZ7K  A1SP2KVKFXXRU1    David C. Sullivan                     0
# 7    8  B006K2ZZ7K  A3JRGQVEQN31IQ   Pamela G. Williams                     0
# 12  13  B0009XLVG0   A327PCT23YH90                   LT                     1
# 14  15  B001GVISJM  A2MUGFV2TDQ47K  Lynrie "Oh HELL no"                     4
# 15  16  B001GVISJM  A1CZX3CP8IKQIJ         Brian A. Lee                     4
# 16  17  B001GVISJM  A3KLWF6WQ5BNYO       Erica Neathery                     0
# 17  18  B001GVISJM   AFKW14U97Z6QO                Becca                     0
# 18  19  B001GVISJM  A2A9X58G2GTBLP              Wolfee1                     0
# 19  20  B001GVISJM  A3IV7CL2C13K2U                 Greg                     0
#
#     HelpfulnessDenominator  Score        Time  \
# 5                        0      4  1342051200
# ...

# %%
#Checking an example duplicate
df.query('ProductId == "B006K2ZZ7K"')
# Out:
#    Id   ProductId         User_Id                    ProfileName  \
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T  Michael D. Bigham "M. Wassir"
# 5   6  B006K2ZZ7K   ADT0SRK1MGOEU                 Twoapennything
# 6   7  B006K2ZZ7K  A1SP2KVKFXXRU1              David C. Sullivan
# 7   8  B006K2ZZ7K  A3JRGQVEQN31IQ             Pamela G. Williams
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 4                     0                       0      5  1350777600
# 5                     0                       0      4  1342051200
# 6                     0                       0      5  1340150400
# 7                     0                       0      5  1336003200
#
#                                          Summary  \
# 4                                    Great taffy
# 5                                     Nice Taffy
# 6  Great!  Just as good as the expensive brands!
# 7                         Wonderful, tasty taffy
#
# ...

# %%
ax = df['Score'].value_counts().head(10)
ax.plot(kind='bar', title='Score N Reviews of Amazon Food')
plt.xlabel('Text')
plt.ylabel('Counts')
plt.show()

# %%
ax = df['Score'].plot(kind = 'hist',bins = 20, title = 'Reviews', color='red')
ax.set_xlabel('%')
# Out:
# Text(0.5, 0, '%')
